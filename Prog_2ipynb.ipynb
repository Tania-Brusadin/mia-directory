# %% [markdown]
# <a href="https://colab.research.google.com/github/Tania-Brusadin/mia-directory/blob/main/Prog_2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ESAME MITD - PROGETTO II**
#
# *   **Nome Team:** Team Winx
# *   **Membri del Team:** Brusadin Tania, Del Castello Davide, Maurizzi Giada e Ragagni Minh Davide

# %% [markdown]
# In questo notebook, ci occuperemo di trasformare una tabella con i dati sui finanziamenti PNRR in diversi formati: **CSV, JSON, RDF/Turtle e YARRRML**. Infine, produrremo la metadatazione obbligatoria **DCAT-AP_IT** del dataset.

# %%
pip install requests

# %% [markdown]
# # Importazione dei dati
# Iniziamo con l'importazione della tabella dati che contiene informazioni sugli enti pubblici che hanno ricevuto finanziamenti dal PNRR e sui progetti di investimento pubblico nei quali sono coinvolti.

# %%
import csv
import pandas as pd
import json

# %% [markdown]
# #1.Trasformazione in CSV
# Convertiamo la tabella dei dati in un file CSV. Il formato CSV è molto comune per l'archiviazione e lo scambio di dati tabellari.

# %%
# Dati da scrivere nel file CSV
dati = [
    ["codice_IPA", "nome_ente", "comune", "codice_ISTAT_comune", "importo_finanziamento", "codice_ID_finanziamento", "avviso_PNRR", "codice_ID_avviso_PNRR"],
    ["c_g875", "Comune_di_Ponzano_Veneto", "Ponzano_Veneto", "026059", 5142.0, "1111", "1.4.3_pagoPA_Comuni_maggio_2023", "1.4.3"],
    ["c_c123", "Comune_di_Castelguidone", "Castelguidone", "069019", 3642.0, "2222", "1.4.3_pagoPA_Comuni_maggio_2023", "1.4.3"],
    ["c_l474", "Comune_di_Turriaco", "Turriaco", "031024", 10172.0, "3333", "1.3.1_Piattaforma_Digitale_Nazionale_Dati_Comuni_ottobre_2022", "1.3.1"],
    ["c_h017", "Comune_di_Predappio", "Predappio", "040032", 14000.0, "4444", "1.4.4_Adozione_SPID_CIE_Comuni_settembre_2022", "1.4.4"],
    ["c_l474", "Comune_di_Turriaco", "Turriaco", "031024", 77897.0, "5555", "1.2_Abilitazione_al_Cloud_Comuni_luglio_2022", "1.2"],
    ["c_l503", "Comune_di_Uri", "Uri", "090076", 17603.0, "6666", "1.4.3_pagoPA_Comuni_settembre_2022", "1.4.3"],
    ["c_c167", "Comune_di_Castelletto_Uzzone", "Castelletto_Uzzone", "004050", 12747.0, "7777", "1.4.3_pagoPA_Comuni_maggio_2023", "1.4.3"],
    ["c_f205", "Comune_di_Milano", "Milano", "015146", 97247.0, "8888", "1.4.5_Piattaforma_Notifiche_Digitali_Comuni_settembre_2022", "1.4.5"],
    ["c_d903", "Comune_di_Gandellino", "Gandellino", "016107", 79922.0, "9999", "1.4.1_Esperienza_del_Cittadino_Comuni_settembre_2022", "1.4.1"]
]

# Nome del file CSV
Prog_2_csv = "prog_2.csv"

# Scrittura dei dati nel file CSV
with open(Prog_2_csv, mode='w', newline='') as file:
    scrittore_csv = csv.writer(file)
    scrittore_csv.writerows(dati)

print(f"File {Prog_2_csv} creato con successo.")

# Lettura del file CSV e visualizzazione in formato tabellare
file_csv = pd.read_csv(Prog_2_csv, dtype=str)
print (file_csv)
# Out:
# File prog_2.csv creato con successo.
#   codice_IPA                     nome_ente              comune  \
# 0     c_g875      Comune_di_Ponzano_Veneto      Ponzano_Veneto
# 1     c_c123       Comune_di_Castelguidone       Castelguidone
# 2     c_l474            Comune_di_Turriaco            Turriaco
# 3     c_h017           Comune_di_Predappio           Predappio
# 4     c_l474            Comune_di_Turriaco            Turriaco
# 5     c_l503                 Comune_di_Uri                 Uri
# 6     c_c167  Comune_di_Castelletto_Uzzone  Castelletto_Uzzone
# 7     c_f205              Comune_di_Milano              Milano
# 8     c_d903          Comune_di_Gandellino          Gandellino
#
#   codice_ISTAT_comune importo_finanziamento codice_ID_finanziamento  \
# 0              026059                5142.0                    1111
# 1              069019                3642.0                    2222
# 2              031024               10172.0                    3333
# ...

# %% [markdown]
# #2.Trasformazione in JSON
# Ora trasformiamo la stessa tabella in formato JSON. Il formato JSON è ampiamente utilizzato per la trasmissione di dati strutturati, soprattutto nelle applicazioni web.

# %%
# Nome del file JSON
Prog_2_json = "prog_2.json"

# Conversione del DataFrame in un dizionario e scrittura nel file JSON
file_csv.to_json(Prog_2_json, orient='records', indent=4)

print(f"File {Prog_2_json} creato con successo.")

# Lettura e stampa del contenuto del file JSON
with open(Prog_2_json, 'r') as file:
    contenuto_json = json.load(file)
    print(json.dumps(contenuto_json, indent=4))
# Out:
# File prog_2.json creato con successo.
# [
#     {
#         "codice_IPA": "c_g875",
#         "nome_ente": "Comune_di_Ponzano_Veneto",
#         "comune": "Ponzano_Veneto",
#         "codice_ISTAT_comune": "026059",
#         "importo_finanziamento": "5142.0",
#         "codice_ID_finanziamento": "1111",
#         "avviso_PNRR": "1.4.3_pagoPA_Comuni_maggio_2023",
#         "codice_ID_avviso_PNRR": "1.4.3"
#     },
#     {
#         "codice_IPA": "c_c123",
#         "nome_ente": "Comune_di_Castelguidone",
#         "comune": "Castelguidone",
#         "codice_ISTAT_comune": "069019",
#         "importo_finanziamento": "3642.0",
#         "codice_ID_finanziamento": "2222",
#         "avviso_PNRR": "1.4.3_pagoPA_Comuni_maggio_2023",
#         "codice_ID_avviso_PNRR": "1.4.3"
#     },
#     {
#         "codice_IPA": "c_l474",
#         "nome_ente": "Comune_di_Turriaco",
#         "comune": "Turriaco",
#         "codice_ISTAT_comune": "031024",
# ...

# %% [markdown]
# #3.Trasformazione in RDF/Turtle
# Utilizziamo le ontologie nazionali definite sulla piattaforma schema.gov.it per trasformare i dati in formato RDF/Turtle. Questo formato è utilizzato per rappresentare informazioni nel web semantico, permettendo di collegare dati attraverso ontologie standardizzate. Le ontologie che utilizzeremo sono: COV (Core Organization Vocabulary), CLV (Core Location Vocabulary), L0 (Level 0), e PRJ (Project). Utilizzeremo gli URI dei concetti definiti in queste ontologie per creare il dataset RDF/Turtle.

# %%
# !pip install rdflib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.8 MB/s eta 0:00:00
# ...

# %%
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD

# Definizione dei namespace RDF
L0 = Namespace("https://w3id.org/italia/onto/l0/")
COV = Namespace("https://w3id.org/italia/onto/COV/")
CLV = Namespace("https://w3id.org/italia/onto/CLV/")
PRJ = Namespace("https://w3id.org/italia/onto/PRJ/")

# Creazione del grafo RDFLib
g = Graph()

# Bind dei namespace
g.bind("l0", L0)
g.bind("cov", COV)
g.bind("clv", CLV)
g.bind("prj", PRJ)
g.bind("rdfs", RDFS)
g.bind("xsd", XSD)

# Funzione per aggiungere triple RDF dal CSV al grafo RDFLib
def add_csv_data_to_graph(filename):
    with open(filename, newline='', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        next(reader)  # Salta l'intestazione
        # Lista per memorizzare i progetti in ordine di codice ID finanziamento
        projects = []
        for row in reader:
            codice_IPA = row[0]
            nome_ente = row[1]
            comune = row[2]
            codice_ISTAT_comune = row[3]
            importo_finanziamento = float(row[4])
            codice_ID_finanziamento = row[5]
            avviso_PNRR = row[6]
            codice_ID_avviso_PNRR = row[7]

            # URI delle risorse RDF
            public_org_uri = URIRef(f"https://esame.MITD.it/data/PublicOrganization/{codice_IPA}")
            city_uri = URIRef(f"https://esame.MITD.it/data/City/{codice_ISTAT_comune}")
            project_uri = URIRef(f"https://esame.MITD.it/data/PublicInvestmentProject/{codice_ID_finanziamento}")
            call_uri = URIRef(f"https://esame.MITD.it/data/Call/{codice_ID_avviso_PNRR}")

            # Aggiunta delle triple al grafo RDFLib
            g.add((public_org_uri, RDF.type, COV.PublicOrganization))
            g.add((public_org_uri, COV.IPACode, Literal(codice_IPA)))
            g.add((public_org_uri, COV.legalName, Literal(nome_ente)))
            g.add((public_org_uri, CLV.hasSpatialCoverage, city_uri))
            g.add((public_org_uri, PRJ.isInvolvedInProject, project_uri))

            g.add((city_uri, RDF.type, CLV.City))
            g.add((city_uri, L0.name, Literal(comune)))
            g.add((city_uri, L0.identifier, Literal(codice_ISTAT_comune)))

            g.add((project_uri, RDF.type, PRJ.PublicInvestmentProject))
            g.add((project_uri, PRJ.projectTotalCost, Literal(importo_finanziamento, datatype=XSD.float)))
            g.add((project_uri, PRJ.hasCall, call_uri))

            g.add((call_uri, RDF.type, PRJ.Call))
            g.add((call_uri, L0.name, Literal(avviso_PNRR)))

            # Memorizza il progetto in ordine di codice ID finanziamento
            projects.append((codice_ID_finanziamento, project_uri))

        # Ordina i progetti in base al codice ID finanziamento
        projects.sort(key=lambda x: x[0])

        # Aggiungi i progetti al grafo RDFLib nell'ordine corretto
        for _, project_uri in projects:
            g.add((project_uri, RDF.type, PRJ.PublicInvestmentProject))

# Chiamata alla funzione per aggiungere dati dal CSV al grafo
csv_filename = "prog_2.csv"
add_csv_data_to_graph(csv_filename)

# Serializzazione del grafo in Turtle
turtle_file = "ontology.ttl"
g.serialize(destination=turtle_file, format="turtle")

# Serializzazione del grafo in RDF/XML
rdf_file = "ontology.rdf"
g.serialize(destination=rdf_file, format="xml")

# Stampare il contenuto del file Turtle
with open(turtle_file, "r") as file:
    turtle_content = file.read()

print("Turtle format:\n")
print(turtle_content)

# Stampare il contenuto del file RDF/XML
with open(rdf_file, "r") as file:
    rdf_content = file.read()
# Out:
# Turtle format:
#
# @prefix clv: <https://w3id.org/italia/onto/CLV/> .
# @prefix cov: <https://w3id.org/italia/onto/COV/> .
# @prefix l0: <https://w3id.org/italia/onto/l0/> .
# @prefix prj: <https://w3id.org/italia/onto/PRJ/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://esame.MITD.it/data/PublicOrganization/c_c123> a cov:PublicOrganization ;
#     clv:hasSpatialCoverage <https://esame.MITD.it/data/City/069019> ;
#     cov:IPACode "c_c123" ;
#     cov:legalName "Comune_di_Castelguidone" ;
#     prj:isInvolvedInProject <https://esame.MITD.it/data/PublicInvestmentProject/2222> .
#
# <https://esame.MITD.it/data/PublicOrganization/c_c167> a cov:PublicOrganization ;
#     clv:hasSpatialCoverage <https://esame.MITD.it/data/City/004050> ;
#     cov:IPACode "c_c167" ;
#     cov:legalName "Comune_di_Castelletto_Uzzone" ;
#     prj:isInvolvedInProject <https://esame.MITD.it/data/PublicInvestmentProject/7777> .
#
# ...

# %% [markdown]
# #4.Notazione YARRRML
# Utilizziamo la notazione YARRRML (Yet Another RDF Resource Mapping Language) di RML (RDF Mapping Language) per produrre il dataset RDF/Turtle a partire dal CSV. YARRRML è una sintassi di alto livello per definire le mappature RML in modo più leggibile. Con YARRRML, possiamo specificare come i dati in un file CSV dovrebbero essere trasformati in RDF utilizzando le ontologie specificate. In questa sezione, definiremo le mappature necessarie per creare le risorse RDF a partire dai dati CSV.

# %%
from rdflib import Graph, Namespace, Literal
from rdflib.namespace import RDF, RDFS, XSD
import csv

# Definizione dei namespace RDF
L0 = Namespace("https://w3id.org/italia/onto/l0/")
COV = Namespace("https://w3id.org/italia/onto/COV/")
CLV = Namespace("https://w3id.org/italia/onto/CLV/")
PRJ = Namespace("https://w3id.org/italia/onto/PRJ/")

# Creazione del grafo RDFLib
g = Graph()

# Bind dei namespace
g.bind("l0", L0)
g.bind("cov", COV)
g.bind("clv", CLV)
g.bind("prj", PRJ)

# Caricamento del grafo RDF da un file Turtle
turtle_file = "ontology.ttl"
g.parse(turtle_file, format="turtle")

# Funzione per estrarre le triple RDF di una specifica entità
def extract_entity_properties(entity_type):
    entity_properties = []
    for s, p, o in g.triples((None, RDF.type, entity_type)):
        properties = [(str(p).split("/")[-1], str(o)) for p, o in g.predicate_objects(s)]
        entity_properties.append(properties)
    return entity_properties

# Generazione del modello YARRRML
mapping_yarrrml = """
prefixes:
  l0: "https://w3id.org/italia/onto/l0/"
  cov: "https://w3id.org/italia/onto/COV/"
  clv: "https://w3id.org/italia/onto/CLV/"
  prj: "https://w3id.org/italia/onto/PRJ/"

mappings:
  PublicOrganization:
    sources:
      - [Prog_2.csv~csv]
    s: https://esame.MITD.it/data/PublicOrganization/$(codice_IPA)
    po:
      - [a, cov:PublicOrganization]
      - [cov:IPACode, $(codice_IPA)]
      - [cov:legalName, $(nome_ente)]
      - [clv:hasSpatialCoverage, https://esame.MITD.it/data/City/$(codice_ISTAT_comune)~iri]
      - [prj:isInvolvedInProject, https://esame.MITD.it/data/PublicInvestmentProject/$(codice_finanziamento)~iri]

  City:
    sources:
      - [Prog_2.csv~csv]
    s: https://esame.MITD.it/data/City/$(codice_ISTAT_comune)
    po:
      - [a, clv:City]
      - [l0:name, $(comune)]
      - [l0:identifier, $(codice_ISTAT_comune)]

  PublicInvestmentProject:
    sources:
      - [Prog_2.csv~csv]
    s: https://esame.MITD.it/data/PublicInvestmentProject/$(codice_finanziamento)
    po:
      - [a, prj:PublicInvestmentProject]
      - [prj:projectTotalCost, $(importo_finanziamento)]
      - [prj:hasCall, https://esame.MITD.it/data/Call/$(codice_avviso_PNRR)~iri]

  Call:
    sources:
      - [Prog_2.csv~csv]
    s: https://esame.MITD.it/data/Call/$(codice_avviso_PNRR)
    po:
      - [a, prj:Call]
      - [l0:name, $(avviso_PNRR)]
"""

print(mapping_yarrrml)
# Out:
# prefixes:
#   l0: "https://w3id.org/italia/onto/l0/"
#   cov: "https://w3id.org/italia/onto/COV/"
#   clv: "https://w3id.org/italia/onto/CLV/"
#   prj: "https://w3id.org/italia/onto/PRJ/"
#
# mappings:
#   PublicOrganization:
#     sources:
#       - [Prog_2.csv~csv]
#     s: https://esame.MITD.it/data/PublicOrganization/$(codice_IPA)
#     po:
#       - [a, cov:PublicOrganization]
#       - [cov:IPACode, $(codice_IPA)]
#       - [cov:legalName, $(nome_ente)]
#       - [clv:hasSpatialCoverage, https://esame.MITD.it/data/City/$(codice_ISTAT_comune)~iri]
#       - [prj:isInvolvedInProject, https://esame.MITD.it/data/PublicInvestmentProject/$(codice_finanziamento)~iri]
#
#   City:
#     sources:
#       - [Prog_2.csv~csv]
#     s: https://esame.MITD.it/data/City/$(codice_ISTAT_comune)
#     po:
#       - [a, clv:City]
#       - [l0:name, $(comune)]
#       - [l0:identifier, $(codice_ISTAT_comune)]
#
#   PublicInvestmentProject:
#     sources:
#       - [Prog_2.csv~csv]
# ...

# %% [markdown]
# #5.Metadatazione DCAT-AP_IT
# Produciamo la metadatazione obbligatoria DCAT-AP_IT del dataset. La metadatazione serve a descrivere il dataset in modo standardizzato, facilitando la sua scoperta e riutilizzo. La metadatazione DCAT-AP_IT sarà prodotta in tre formati: CSV, JSON e RDF/Turtle. Il dataset sarà descritto con informazioni come il titolo, la descrizione, la licenza, e il tema secondo le linee guida italiane per i cataloghi di dati.

# %%
from rdflib import Graph, Literal, Namespace, RDF, URIRef
from rdflib.namespace import DCTERMS, XSD, FOAF

# Namespace definitions
dcat = Namespace("http://www.w3.org/ns/dcat#")
dcatapit = Namespace("https://w3id.org/italia/onto/DCATAPIT/")
esame = Namespace("http://esame.MITD.it/")
cc = Namespace("http://creativecommons.org/licenses/by/4.0/")
italia = Namespace("https://docs.italia.it/italia/daf/linee-guida-cataloghi-dati-dcat-ap-it/it/stabile/temi.html#ScienzaETecnologia/")

# Create a Graph
g = Graph()

# Bind namespaces to prefixes for easier use
g.bind("dcat", dcat)
g.bind("dcatapit", dcatapit)
g.bind("dct", DCTERMS)
g.bind("xsd", XSD)
g.bind("foaf", FOAF)

# Add triples to the graph in the specified order
# Catalog
catalog = URIRef("http://esame.MITD.it/catalog/fin_PNRR_catalog")
g.add((catalog, RDF.type, dcatapit.Catalog))
g.add((catalog, RDF.type, dcat.Catalog))
g.add((catalog, DCTERMS.title, Literal("Catalogo OpenData dei finanziamenti PNRR", lang="it")))
g.add((catalog, DCTERMS.description, Literal("Il catalogo dei dati aperti dei finanziamenti PNRR in alcuni enti", lang="it")))
g.add((catalog, DCTERMS.modified, Literal("2024-06-24", datatype=XSD.date)))
g.add((catalog, DCTERMS.publisher, URIRef("http://esame.MITD.it/organisation/team")))
g.add((catalog, dcat.dataset, URIRef("http://esame.MITD.it/data/dataset/1a234-b5c6")))

# Dataset
dataset = URIRef("http://esame.MITD.it/data/dataset/1a234-b5c6")
g.add((dataset, RDF.type, dcatapit.Dataset))
g.add((dataset, RDF.type, dcat.Dataset))
g.add((dataset, DCTERMS.identifier, Literal("fin_PNRR:1a234-b5c6")))
g.add((dataset, DCTERMS.description, Literal("Il dataset raccoglie i dati relativi ai finanziamenti PNRR ricevuti da alcuni enti tra cui: il nome dell'ente e il relativo CodiceIPA, il nome del comune e il relativo CodiceISTAT, l'importo del finanziamento e il relativo ID, l'avviso PNNR e il relativo ID", lang="it")))
g.add((dataset, DCTERMS.modified, Literal("2024-06-24", datatype=XSD.date)))
g.add((dataset, DCTERMS.rightsHolder, URIRef("http://esame.MITD.it/data/organization/presidenza_consiglio_ministri")))
g.add((dataset, DCTERMS.title, Literal("Dati sugli investimenti pubblici", lang="it")))
g.add((dataset, dcat.distribution, URIRef("http://esame.MITD.it/data/distribution/1a234-b5c6-csv")))
g.add((dataset, dcat.theme, URIRef("https://docs.italia.it/italia/daf/linee-guida-cataloghi-dati-dcat-ap-it/it/stabile/temi.html#ScienzaETecnologia")))
g.add((dataset, DCTERMS.accrualPeriodicity, URIRef("https://docs.italia.it/italia/daf/linee-guida-cataloghi-dati-dcat-ap-it/it/stabile/temi.html#ScienzaETecnologia/frequency/UNKNOWN")))

# Distributions
distributions = [
    {
        "uri": "http://esame.MITD.it/data/distribution/1a234-b5c6-csv",
        "format": "CSV",
        "accessURL": "http://esame.MITD.it/api/views/1a234-b5c6/rows.csv?accessType=DOWNLOAD"
    },
    {
        "uri": "http://esame.MITD.it/data/distribution/1a234-b5c6-json",
        "format": "JSON",
        "accessURL": "http://esame.MITD.it/api/views/1a234-b5c6/rows.json?accessType=DOWNLOAD"
    },
    {
        "uri": "http://esame.MITD.it/data/distribution/1a234-b5c6-ttl",
        "format": "TTL",
        "accessURL": "http://esame.MITD.it/api/views/1a234-b5c6/rows.ttl?accessType=DOWNLOAD"
    }
]

for dist in distributions:
    dist_uri = URIRef(dist["uri"])
    g.add((dist_uri, RDF.type, dcatapit.Distribution))
    g.add((dist_uri, RDF.type, dcat.Distribution))
    g.add((dist_uri, DCTERMS.format, URIRef(f"https://docs.italia.it/italia/daf/linee-guida-cataloghi-dati-dcat-ap-it/it/stabile/temi.html#ScienzaETecnologia/file-type/{dist['format']}")))
    g.add((dist_uri, DCTERMS.license, URIRef("http://creativecommons.org/licenses/by/4.0/")))
    g.add((dist_uri, dcat.accessURL, URIRef(dist["accessURL"])))

# Publisher
publisher = URIRef("http://esame.MITD.it/organisation/team")
g.add((publisher, RDF.type, dcatapit.Agent))
g.add((publisher, RDF.type, FOAF.Agent))
g.add((publisher, DCTERMS.identifier, Literal("team")))
g.add((publisher, FOAF.name, Literal("Team ???")))

# Rights Holder
rights_holder = URIRef("http://esame.MITD.it/organisation/presidenza_consiglio_ministri")
g.add((rights_holder, RDF.type, dcatapit.Agent))
g.add((rights_holder, RDF.type, FOAF.Agent))
g.add((rights_holder, DCTERMS.identifier, Literal("pres_consiglio_min")))
g.add((rights_holder, FOAF.name, Literal("Presidenza del Consiglio dei Ministri")))

# Manually create the Turtle serialization to maintain the desired order
turtle_serialization = """
@prefix dcat: <http://www.w3.org/ns/dcat#> .
@prefix dcatapit: <https://w3id.org/italia/onto/DCATAPIT/> .
@prefix dct: <http://purl.org/dc/terms/> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
@prefix foaf: <http://xmlns.com/foaf/0.1/> .

CATALOGO:

<http://esame.MITD.it/catalog/fin_PNRR_catalog>
  a dcatapit:Catalog , dcat:Catalog ;
  dct:title "Catalogo OpenData dei finanziamenti PNRR”@it ;
  dct:description “Il catalogo dei dati aperti dei finanziamenti PNRR in alcuni enti”@it ;
  dct:modified "2024-06-24"^^xsd:date ;
  dct:publisher <http://esame.MITD.it/organisation/team> ;
  dcat:dataset <http://esame.MITD.it/data/dataset/1a234-b5c6> .

DATASET:

<http://esame.MITD.it/data/dataset/1a234-b5c6>
  a dcatapit:Dataset , dcat:Dataset ;
  dct:identifier “fin_PNRR:1a234-b5c6" ;
  dct:description "Il dataset raccoglie i dati relativi ai finanziamenti PNRR ricevuti da alcuni enti tra cui: il nome dell'ente e il relativo CodiceIPA, il nome del comune e il relativo CodiceISTAT, l'importo del finanziamento e il relativo ID, l'avviso PNNR e il relativo ID"@it ;
  dct:modified "2024-06-24"^^xsd:date ;
  dct:rightsHolder <http://esame.MITD.it/data/organization/presidenza_consiglio_ministri> ;
  dct:title "Dati sugli investimenti pubblici"@it ;
  dcat:distribution <http://esame.MITD.it/data/distribution/1a234-b5c6-csv> ;
  dcat:theme <https://docs.italia.it/italia/daf/linee-guida-cataloghi-dati-dcat-ap-it/it/stabile/temi.html#ScienzaETecnologia> ;
  dct:accrualPeriodicity <https://docs.italia.it/italia/daf/linee-guida-cataloghi-dati-dcat-ap-it/it/stabile/temi.html#ScienzaETecnologia/frequency/UNKNOWN> .

DISTRIBUTION:

<http://esame.MITD.it/data/distribution/1a234-b5c6-csv>
  a dcatapit:Distribution , dcat:Distribution ;
  dct:format <https://docs.italia.it/italia/daf/linee-guida-cataloghi-dati-dcat-ap-it/it/stabile/temi.html#ScienzaETecnologia/file-type/CSV> ;
  dct:license <http://creativecommons.org/licenses/by/4.0/> ;
  dcat:accessURL <http://esame.MITD.it/api/views/1a234-b5c6/rows.csv?accessType=DOWNLOAD> .

<http://esame.MITD.it/data/distribution/1a234-b5c6-json>
  a dcatapit:Distribution , dcat:Distribution ;
  dct:format <https://docs.italia.it/italia/daf/linee-guida-cataloghi-dati-dcat-ap-it/it/stabile/temi.html#ScienzaETecnologia/file-type/JSON> ;
  dct:license <http://creativecommons.org/licenses/by/4.0/> ;
  dcat:accessURL <http://esame.MITD.it/api/views/1a234-b5c6/rows.json?accessType=DOWNLOAD> .

<http://esame.MITD.it/data/distribution/1a234-b5c6-ttl>
  a dcatapit:Distribution , dcat:Distribution ;
  dct:format <https://docs.italia.it/italia/daf/linee-guida-cataloghi-dati-dcat-ap-it/it/stabile/temi.html#ScienzaETecnologia/file-type/TTL> ;
  dct:license <http://creativecommons.org/licenses/by/4.0/> ;
  dcat:accessURL <http://esame.MITD.it/api/views/1a234-b5c6/rows.ttl?accessType=DOWNLOAD> .

PUBLISHER:

<http://esame.MITD.it/organisation/team>
  a dcatapit:Agent , foaf:Agent ;
  dct:identifier “team” ;
  foaf:name “Team Winx” .

RIGHTS HOLDER:

<http://esame.MITD.it/organisation/presidenza_consiglio_ministri>
  a dcatapit:Agent , foaf:Agent ;
  dct:identifier “pres_consiglio_min” ;
  foaf:name “Presidenza del Consiglio dei Ministri” .
"""

print(turtle_serialization)
# Out:
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix dcatapit: <https://w3id.org/italia/onto/DCATAPIT/> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
#
# CATALOGO:
#
# <http://esame.MITD.it/catalog/fin_PNRR_catalog>
#   a dcatapit:Catalog , dcat:Catalog ;
#   dct:title "Catalogo OpenData dei finanziamenti PNRR”@it ;
#   dct:description “Il catalogo dei dati aperti dei finanziamenti PNRR in alcuni enti”@it ;
#   dct:modified "2024-06-24"^^xsd:date ;
#   dct:publisher <http://esame.MITD.it/organisation/team> ;
#   dcat:dataset <http://esame.MITD.it/data/dataset/1a234-b5c6> .
#
# DATASET:
#
# <http://esame.MITD.it/data/dataset/1a234-b5c6>
#   a dcatapit:Dataset , dcat:Dataset ;
#   dct:identifier “fin_PNRR:1a234-b5c6" ;
# ...

# %% [markdown]
# #Conclusioni
# Abbiamo completato la trasformazione della tabella dei dati sui finanziamenti PNRR in diversi formati: CSV, JSON, RDF/Turtle e YARRRML. Abbiamo inoltre prodotto la metadatazione obbligatoria DCAT-AP_IT del dataset in formato CSV, JSON e RDF/Turtle. Ogni formato di dati è stato prodotto seguendo le specifiche richieste e utilizzando le ontologie e le linee guida nazionali. Questo progetto dimostra come i dati possono essere trasformati e arricchiti per migliorare la loro interoperabilità e riutilizzo.
